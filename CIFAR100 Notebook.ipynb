# %% [markdown]
# ## CSC345 - Big Data & Machine Learning - Coursework: Image Classification

# %% [markdown]
# ## Tim Deville (2003506)

# %% [markdown]
# # Method A: Convolutional Neural Network

# %% [markdown]
# ## Step 1: Dataset Preprocessing

# %% [markdown]
# ### Import libraries:

# %%
import numpy as np
import seaborn as sns
import csv
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, MaxPool2D, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report,confusion_matrix, ConfusionMatrixDisplay
import skimage.feature
from sklearn.svm import SVC
from sklearn.decomposition import PCA

# %% [markdown]
# ### Load dataset from file, check file shape:

# %%
# Function for loading the coarse and fine data labels from the provided csv files
def read_text_labels():
    coarse_file = open("coarse_labels.csv", "r")
    fine_file = open("fine_labels.csv", "r")

    coarse = list(csv.reader(coarse_file, delimiter=","))
    fine = list(csv.reader(fine_file, delimiter=","))

    coarse_file.close()
    fine_file.close()
    return coarse[0], fine[0]

# %%
# Training and testing image datasets
X_train = np.load('trnImage.npy')
X_test = np.load('tstImage.npy')


# Labels data (numerical) for coarse and fine datasets
y_train_coarse = np.load('trnLabel_coarse.npy')
y_test_coarse = np.load('tstLabel_coarse.npy')
y_train_fine = np.load('trnLabel_fine.npy')
y_test_fine = np.load('tstLabel_fine.npy')

# Generate list of text labels from csv file
coarse_list, fine_list = read_text_labels()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [3], line 2
#       1 # Training and testing image datasets
# ----> 2 X_train = np.load('trnImage.npy')
#       3 X_test = np.load('tstImage.npy')
#       6 # Labels data (numerical) for coarse and fine datasets
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\npyio.py:390, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     388     own_fid = False
#     389 else:
# --> 390     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     391     own_fid = True
#     393 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'trnImage.npy'

# %%
# Function to check the shape of the image data
def check_x_data_shape():
    print('X_train shape:', X_train.shape)
    print('X_test shape:', X_test.shape)

# %%
# Function to check the shape of the label data
def check_y_data_shape():
    print('y_train_fine shape:', y_train_fine.shape)
    print('y_test_fine shape:', y_test_fine.shape)
    print('y_train_course shape:', y_train_coarse.shape)
    print('y_test_course shape:', y_test_coarse.shape)

# %% [markdown]
# ### Swap order of input shape ready for CNN:

# %%
check_x_data_shape()
# Out:
# X_train shape: (32, 32, 3, 50000)
# X_test shape: (32, 32, 3, 10000)

# %%
# reshape data for CNN - E.g. (50000, 32, 32, 3) rather than (32,32,3,50000)
X_train = np.transpose(X_train, axes=[3,0,1,2])
X_test = np.transpose(X_test, axes=[3,0,1,2])
check_x_data_shape()
# Out:
# X_train shape: (50000, 32, 32, 3)
# X_test shape: (10000, 32, 32, 3)

# %% [markdown]
# ### Change labels to one-hot encoding:

# %%
# Keep a copy of the original test labels to display later
y_test_coarse_original = y_test_coarse.copy()
y_test_fine_original = y_test_fine.copy()

# Change to onehot encoding for neural network training
y_train_coarse = to_categorical(y_train_coarse)
y_test_coarse = to_categorical(y_test_coarse)
y_train_fine = to_categorical(y_train_fine)
y_test_fine = to_categorical(y_test_fine)

# %% [markdown]
# ### Check images and labels have been correctly set up

# %%
# Function to select 16 random images from the test dataset.
# Displays the image with the corresponding text label
def display_random_images():
    plt.figure(figsize=(8, 8))
    for i in range (16):
        rand_num = np.random.randint(0, 10000)
        image = X_test[rand_num]
        label = fine_list[y_test_fine_original[rand_num]]
        plt.subplot(4,4, i+1)
        plt.tight_layout()
        plt.axis('off')
        plt.imshow(image)
        plt.title(label)

# %%
display_random_images()

# %% [markdown]
# ## Step 2: Build CNN model

# %%
# Function to create and return a CNN model
def create_cnn(num_classes):
    model = Sequential()
    # First Convolution layer
    model.add(Conv2D(filters=64, kernel_size=(3, 3), input_shape=(32, 32, 3), activation='relu'))
    model.add(MaxPool2D(pool_size=(3, 3)))
    # Second Convolution layer
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPool2D(pool_size=(3, 3)))
    # Flatten the data before passing to dense layer
    model.add(Flatten())
    # Dense layer
    model.add(Dense(512, activation='relu'))
    # Apply batch normalisation before final dense layer
    model.add(BatchNormalization())
    # Final dense layer to classify images based on number of classes in fine/coarse dataset
    model.add(Dense(num_classes, activation='softmax'))

    model.summary()
    # Compile using Adam optimiser
    model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  metrics=tf.keras.metrics.CategoricalAccuracy())

    return model

# %% [markdown]
# ### Fit training data to X_train using coarse labels

# %%
## Stops the training process early if the validation loss is not improving.
earlyStopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

# %%
coarse_model = create_cnn(20)
coarse_history=coarse_model.fit(X_train, y_train_coarse, epochs=20, validation_split=0.2, verbose=1, shuffle=True, callbacks=[earlyStopping])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 64)        1792
#
#  max_pooling2d (MaxPooling2D  (None, 10, 10, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 64)          36928
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 512)               131584
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dense_1 (Dense)             (None, 20)                10260
#
# =================================================================
# Total params: 182,612
# Trainable params: 181,588
# Non-trainable params: 1,024
# _________________________________________________________________
# Epoch 1/20
# 1250/1250 [==============================] - 13s 10ms/step - loss: 2.4466 - categorical_accuracy: 0.2515 - val_loss: 2.3034 - val_categorical_accuracy: 0.2951
# Epoch 2/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 2.1330 - categorical_accuracy: 0.3485 - val_loss: 2.1587 - val_categorical_accuracy: 0.3363
# Epoch 3/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.9894 - categorical_accuracy: 0.3883 - val_loss: 2.0502 - val_categorical_accuracy: 0.3688
# Epoch 4/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.8884 - categorical_accuracy: 0.4184 - val_loss: 2.0291 - val_categorical_accuracy: 0.3873
# Epoch 5/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 1.8167 - categorical_accuracy: 0.4396 - val_loss: 1.8927 - val_categorical_accuracy: 0.4106
# Epoch 6/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.7544 - categorical_accuracy: 0.4572 - val_loss: 1.8802 - val_categorical_accuracy: 0.4244
# Epoch 7/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.7008 - categorical_accuracy: 0.4727 - val_loss: 1.8310 - val_categorical_accuracy: 0.4389
# Epoch 8/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.6586 - categorical_accuracy: 0.4856 - val_loss: 1.7937 - val_categorical_accuracy: 0.4477
# Epoch 9/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 1.6149 - categorical_accuracy: 0.4974 - val_loss: 1.7553 - val_categorical_accuracy: 0.4605
# Epoch 10/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.5737 - categorical_accuracy: 0.5120 - val_loss: 1.9614 - val_categorical_accuracy: 0.4142
# Epoch 11/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 1.5411 - categorical_accuracy: 0.5189 - val_loss: 1.7498 - val_categorical_accuracy: 0.4665
# Epoch 12/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 1.5059 - categorical_accuracy: 0.5298 - val_loss: 1.8219 - val_categorical_accuracy: 0.4471
# Epoch 13/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 1.4722 - categorical_accuracy: 0.5401 - val_loss: 1.7896 - val_categorical_accuracy: 0.4538
# Epoch 14/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 1.4386 - categorical_accuracy: 0.5504 - val_loss: 1.6864 - val_categorical_accuracy: 0.4843
# Epoch 15/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.4103 - categorical_accuracy: 0.5601 - val_loss: 1.6907 - val_categorical_accuracy: 0.4819
# Epoch 16/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.3823 - categorical_accuracy: 0.5685 - val_loss: 1.6836 - val_categorical_accuracy: 0.4878
# Epoch 17/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.3534 - categorical_accuracy: 0.5767 - val_loss: 1.7470 - val_categorical_accuracy: 0.4711
# Epoch 18/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.3283 - categorical_accuracy: 0.5839 - val_loss: 1.6916 - val_categorical_accuracy: 0.4874
# Epoch 19/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.3002 - categorical_accuracy: 0.5924 - val_loss: 1.7261 - val_categorical_accuracy: 0.4799

# %% [markdown]
# ### Use the same CNN model to train for fine label dataset

# %%
fine_model = create_cnn(100)
fine_history=fine_model.fit(X_train, y_train_fine, epochs=20, validation_split=0.2, verbose=1, shuffle=True, callbacks=[earlyStopping])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 30, 30, 64)        1792
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_3 (Dense)             (None, 100)               51300
#
# =================================================================
# Total params: 223,652
# Trainable params: 222,628
# Non-trainable params: 1,024
# _________________________________________________________________
# Epoch 1/20
# 1250/1250 [==============================] - 13s 10ms/step - loss: 3.9447 - categorical_accuracy: 0.1137 - val_loss: 3.6627 - val_categorical_accuracy: 0.1562
# Epoch 2/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 3.4249 - categorical_accuracy: 0.2011 - val_loss: 3.3522 - val_categorical_accuracy: 0.2060
# Epoch 3/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 3.1547 - categorical_accuracy: 0.2486 - val_loss: 3.1679 - val_categorical_accuracy: 0.2398
# Epoch 4/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 2.9652 - categorical_accuracy: 0.2833 - val_loss: 3.0578 - val_categorical_accuracy: 0.2695
# Epoch 5/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 2.8178 - categorical_accuracy: 0.3126 - val_loss: 2.9378 - val_categorical_accuracy: 0.2829
# Epoch 6/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 2.6932 - categorical_accuracy: 0.3340 - val_loss: 2.8307 - val_categorical_accuracy: 0.3117
# Epoch 7/20
# 1250/1250 [==============================] - 11s 9ms/step - loss: 2.5930 - categorical_accuracy: 0.3562 - val_loss: 2.8179 - val_categorical_accuracy: 0.3089
# Epoch 8/20
# 1250/1250 [==============================] - 11s 9ms/step - loss: 2.5015 - categorical_accuracy: 0.3756 - val_loss: 2.7494 - val_categorical_accuracy: 0.3279
# Epoch 9/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 2.4233 - categorical_accuracy: 0.3903 - val_loss: 2.6616 - val_categorical_accuracy: 0.3422
# Epoch 10/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 2.3570 - categorical_accuracy: 0.4060 - val_loss: 2.6553 - val_categorical_accuracy: 0.3463
# Epoch 11/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 2.2978 - categorical_accuracy: 0.4183 - val_loss: 2.7327 - val_categorical_accuracy: 0.3380
# Epoch 12/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 2.2414 - categorical_accuracy: 0.4303 - val_loss: 2.6658 - val_categorical_accuracy: 0.3442
# Epoch 13/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 2.1875 - categorical_accuracy: 0.4399 - val_loss: 2.5914 - val_categorical_accuracy: 0.3607
# Epoch 14/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 2.1352 - categorical_accuracy: 0.4518 - val_loss: 2.6185 - val_categorical_accuracy: 0.3553
# Epoch 15/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 2.0934 - categorical_accuracy: 0.4616 - val_loss: 2.6188 - val_categorical_accuracy: 0.3565
# Epoch 16/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 2.0478 - categorical_accuracy: 0.4721 - val_loss: 2.5696 - val_categorical_accuracy: 0.3647
# Epoch 17/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 1.9989 - categorical_accuracy: 0.4816 - val_loss: 2.6185 - val_categorical_accuracy: 0.3570
# Epoch 18/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.9596 - categorical_accuracy: 0.4924 - val_loss: 2.5425 - val_categorical_accuracy: 0.3672
# Epoch 19/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.9217 - categorical_accuracy: 0.4998 - val_loss: 2.6112 - val_categorical_accuracy: 0.3660
# Epoch 20/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.8869 - categorical_accuracy: 0.5074 - val_loss: 2.5441 - val_categorical_accuracy: 0.3772

# %% [markdown]
# # Step 3a: Evaluate Training Performance & Accuracy: Coarse Label Dataset

# %% [markdown]
# ### Evaluate trained model accuracy

# %%
coarse_results = coarse_model.evaluate(X_test, y_test_coarse)
print(f'Test set loss: {coarse_results[0]:0.2f}, test set accuracy: {coarse_results[1]*100:0.2f}%')
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.7241 - categorical_accuracy: 0.4778
# Test set loss: 1.72, test set accuracy: 47.78%

# %% [markdown]
# ### Plot training Metrics

# %%
# Function to plot the training data
def plot_training_data(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=[10,5])

    for ax in axes:
        ax.set_xlabel('Epoch')
        ax.set_ylabel('Accuracy')

    axes[0].set_title("Accuracy Curves")
    axes[0].plot(history.history['categorical_accuracy'])
    axes[0].plot(history.history['val_categorical_accuracy'])
    axes[0].legend(['Training Accuracy',
                    'Validation Accuracy'])

    axes[1].set_title("Loss Curves")
    axes[1].plot(history.history['loss'])
    axes[1].plot(history.history['val_loss'])
    axes[1].legend(['Training Loss',
                    'Validation Loss'])

# %%
plot_training_data(coarse_history)

# %% [markdown]
# ### Show classification Report

# %%
coarse_predictions = coarse_model.predict(X_test)
predicted_classes = coarse_predictions.argmax(axis=1)
print(classification_report(y_test_coarse_original,predicted_classes))
# Out:
# 313/313 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.48      0.35      0.41       500
#            1       0.57      0.40      0.47       500
#            2       0.59      0.78      0.67       500
#            3       0.31      0.64      0.41       500
#            4       0.63      0.59      0.61       500
#            5       0.38      0.38      0.38       500
#            6       0.48      0.59      0.53       500
#            7       0.36      0.59      0.44       500
#            8       0.41      0.44      0.43       500
#            9       0.61      0.52      0.56       500
#           10       0.70      0.69      0.69       500
#           11       0.54      0.26      0.35       500
#           12       0.48      0.29      0.37       500
#           13       0.32      0.21      0.26       500
#           14       0.53      0.58      0.55       500
#           15       0.39      0.21      0.27       500
#           16       0.34      0.24      0.28       500
#           17       0.75      0.80      0.77       500
#           18       0.50      0.44      0.47       500
#           19       0.40      0.56      0.47       500
#
#     accuracy                           0.48     10000
#    macro avg       0.49      0.48      0.47     10000
# weighted avg       0.49      0.48      0.47     10000

# %% [markdown]
# ### Plot heatmap for coarse label confusion matrix (normalised across prediction columns)

# %%
coarse_confusion_matrix = confusion_matrix(y_test_coarse_original,predicted_classes, normalize='pred')
coarse_matrix_plot = ConfusionMatrixDisplay(confusion_matrix=coarse_confusion_matrix, display_labels=coarse_list)
fig, ax = plt.subplots(figsize=(12,10))
plt.title("Confusion Matrix for CNN trained on coarse labels")
coarse_matrix_plot.plot(ax=ax, xticks_rotation='vertical', values_format= '.2f', cmap="Blues")
plt.show()

# %% [markdown]
# # Step 3b: Evaluate Training Performance & Accuracy: Fine Label Dataset

# %% [markdown]
# ### Evaluate result accuracy

# %%
fine_results = fine_model.evaluate(X_test, y_test_fine)
print(f'Test set loss: {fine_results[0]:0.2f}, test set accuracy: {fine_results[1]*100:0.2f}%')
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 2.5136 - categorical_accuracy: 0.3783
# Test set loss: 2.51, test set accuracy: 37.83%

# %% [markdown]
# ### Plot training Metrics

# %%
plot_training_data(fine_history)

# %% [markdown]
# ### Show classification Report

# %%
fine_predictions = fine_model.predict(X_test)
fine_predicted_classes = fine_predictions.argmax(axis=1)
print(classification_report(y_test_fine_original,fine_predicted_classes))
# Out:
# 313/313 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.74      0.67      0.71       100
#            1       0.43      0.55      0.48       100
#            2       0.28      0.18      0.22       100
#            3       0.22      0.17      0.19       100
#            4       0.27      0.19      0.22       100
#            5       0.22      0.39      0.28       100
#            6       0.31      0.38      0.34       100
#            7       0.51      0.32      0.39       100
#            8       0.35      0.56      0.43       100
#            9       0.58      0.48      0.52       100
#           10       0.23      0.15      0.18       100
#           11       0.38      0.10      0.16       100
#           12       0.49      0.39      0.44       100
#           13       0.29      0.30      0.30       100
#           14       0.28      0.32      0.30       100
#           15       0.27      0.21      0.24       100
#           16       0.34      0.54      0.42       100
#           17       0.46      0.71      0.56       100
#           18       0.29      0.28      0.28       100
#           19       0.22      0.21      0.21       100
#           20       0.64      0.54      0.59       100
#           21       0.54      0.53      0.54       100
#           22       0.30      0.31      0.31       100
#           23       0.75      0.44      0.55       100
#           24       0.37      0.70      0.48       100
#           25       0.32      0.29      0.31       100
#           26       0.32      0.29      0.30       100
#           27       0.29      0.16      0.21       100
#           28       0.46      0.59      0.52       100
#           29       0.25      0.37      0.30       100
#           30       0.41      0.48      0.44       100
#           31       0.29      0.33      0.31       100
#           32       0.30      0.26      0.28       100
#           33       0.26      0.48      0.34       100
#           34       0.52      0.30      0.38       100
#           35       0.25      0.22      0.23       100
#           36       0.38      0.24      0.29       100
#           37       0.37      0.16      0.22       100
#           38       0.15      0.13      0.14       100
#           39       0.69      0.33      0.45       100
#           40       0.31      0.28      0.29       100
#           41       0.61      0.52      0.56       100
#           42       0.32      0.34      0.33       100
#           43       0.43      0.36      0.39       100
#           44       0.24      0.14      0.18       100
#           45       0.25      0.12      0.16       100
#           46       0.37      0.19      0.25       100
#           47       0.44      0.60      0.51       100
#           48       0.42      0.70      0.53       100
#           49       0.45      0.59      0.51       100
#           50       0.15      0.09      0.11       100
#           51       0.43      0.26      0.32       100
#           52       0.55      0.51      0.53       100
#           53       0.51      0.74      0.60       100
#           54       0.51      0.45      0.48       100
#           55       0.15      0.06      0.09       100
#           56       0.41      0.58      0.48       100
#           57       0.36      0.44      0.40       100
#           58       0.39      0.50      0.44       100
#           59       0.33      0.31      0.32       100
#           60       0.66      0.74      0.70       100
#           61       0.40      0.58      0.47       100
#           62       0.31      0.71      0.43       100
#           63       0.33      0.35      0.34       100
#           64       0.22      0.13      0.16       100
#           65       0.18      0.26      0.21       100
#           66       0.50      0.37      0.43       100
#           67       0.42      0.31      0.36       100
#           68       0.61      0.62      0.62       100
#           69       0.59      0.52      0.55       100
#           70       0.48      0.31      0.38       100
#           71       0.57      0.65      0.61       100
#           72       0.37      0.11      0.17       100
#           73       0.42      0.30      0.35       100
#           74       0.19      0.26      0.22       100
#           75       0.58      0.53      0.55       100
#           76       0.63      0.67      0.65       100
#           77       0.29      0.19      0.23       100
#           78       0.22      0.18      0.20       100
#           79       0.23      0.49      0.31       100
#           80       0.32      0.10      0.15       100
#           81       0.41      0.44      0.43       100
#           82       0.60      0.79      0.68       100
#           83       0.36      0.32      0.34       100
#           84       0.19      0.30      0.23       100
#           85       0.44      0.44      0.44       100
#           86       0.39      0.40      0.39       100
#           87       0.46      0.38      0.42       100
#           88       0.29      0.44      0.35       100
#           89       0.29      0.43      0.34       100
#           90       0.29      0.23      0.26       100
#           91       0.51      0.40      0.45       100
#           92       0.30      0.21      0.25       100
#           93       0.30      0.15      0.20       100
#           94       0.47      0.85      0.60       100
#           95       0.66      0.38      0.48       100
#           96       0.37      0.29      0.33       100
#           97       0.42      0.35      0.38       100
#           98       0.23      0.14      0.17       100
#           99       0.27      0.48      0.35       100
#
#     accuracy                           0.38     10000
#    macro avg       0.38      0.38      0.37     10000
# weighted avg       0.38      0.38      0.37     10000

# %% [markdown]
# ### Plot heatmap for a random subset of 20 out of 100 fine labels (too large to display all 100 classes)

# %%
fine_confusion_matrix = confusion_matrix(y_test_fine_original,fine_predicted_classes, normalize='pred')
rand_i = np.random.randint(0, y_test_fine[0].size - 20)
print(rand_i)

first_20_matrix = fine_confusion_matrix[rand_i: rand_i+20, rand_i: rand_i+20]

fine_matrix_plot = ConfusionMatrixDisplay(confusion_matrix=first_20_matrix, display_labels=fine_list[rand_i:rand_i+20])
fig, ax = plt.subplots(figsize=(12,10))
fine_matrix_plot.plot(ax=ax, xticks_rotation='vertical', values_format='.2f', cmap="Blues")
plt.show()
# Out:
# 52

# %% [markdown]
# # Step 4: Test classifier on random images from test datasets

# %%
def predict_class_label_svm(img, cnn_model, is_fine=True):
    predictions = cnn_model.predict(img.reshape(1,32,32,3))
    class_prob = np.amax(predictions, axis=1)
    class_prob = np.round(class_prob[0], 4)
    print(class_prob)
    class_prediction = int(np.argmax(predictions,axis=1))

    if is_fine:
        return fine_list[class_prediction], class_prob*100
    else:
        return coarse_list[class_prediction], class_prob*100

# %%
def classify_image_test_svm(model, is_fine = True):
    plt.figure(figsize=(12, 10))
    for i in range (16):
        rand_num = np.random.randint(0, 10000)
        test_image = X_test[rand_num]
        predicted_label, probability = predict_class_label_svm(X_test[rand_num], model, is_fine)
        if is_fine:
            actual_label = fine_list[(y_test_fine_original[rand_num])]
        else:
            actual_label = coarse_list[(y_test_coarse_original[rand_num])]
        plt.subplot(4,4, i+1)
        plt.tight_layout()
        plt.xticks([])
        plt.yticks([])
        plt.imshow(test_image)
        plt.title("Actual: {}".format(actual_label))
        plt.xlabel("Predicted: {0}, {1:.2f}%".format(predicted_label, probability))

# %% [markdown]
# ### Coarse Labelled Images

# %%
classify_image_test_svm(coarse_model, is_fine=False)
# Out:
# 1/1 [==============================] - 0s 13ms/step
# 0.7654
# 1/1 [==============================] - 0s 15ms/step
# 0.4415
# 1/1 [==============================] - 0s 12ms/step
# 0.6598
# 1/1 [==============================] - 0s 13ms/step
# 0.5097
# 1/1 [==============================] - 0s 13ms/step
# 0.596
# 1/1 [==============================] - 0s 12ms/step
# 0.9625
# 1/1 [==============================] - 0s 11ms/step
# 0.2789
# 1/1 [==============================] - 0s 11ms/step
# 0.2878
# 1/1 [==============================] - 0s 11ms/step
# 0.8891
# 1/1 [==============================] - 0s 12ms/step
# 0.9911
# 1/1 [==============================] - 0s 12ms/step
# 0.2939
# 1/1 [==============================] - 0s 13ms/step
# 0.9046
# 1/1 [==============================] - 0s 13ms/step
# 0.8685
# 1/1 [==============================] - 0s 11ms/step
# 0.3516
# 1/1 [==============================] - 0s 12ms/step
# 0.9122
# 1/1 [==============================] - 0s 12ms/step
# 0.3494

# %% [markdown]
# ### Fine Labelled Images

# %%
classify_image_test_svm(fine_model, is_fine=True)
# Out:
# 1/1 [==============================] - 0s 12ms/step
# 0.325
# 1/1 [==============================] - 0s 12ms/step
# 0.8054
# 1/1 [==============================] - 0s 12ms/step
# 0.3077
# 1/1 [==============================] - 0s 12ms/step
# 0.7716
# 1/1 [==============================] - 0s 11ms/step
# 0.898
# 1/1 [==============================] - 0s 14ms/step
# 0.9343
# 1/1 [==============================] - 0s 12ms/step
# 0.335
# 1/1 [==============================] - 0s 12ms/step
# 0.6669
# 1/1 [==============================] - 0s 12ms/step
# 0.1766
# 1/1 [==============================] - 0s 11ms/step
# 0.2946
# 1/1 [==============================] - 0s 11ms/step
# 0.7687
# 1/1 [==============================] - 0s 12ms/step
# 0.7595
# 1/1 [==============================] - 0s 13ms/step
# 0.9187
# 1/1 [==============================] - 0s 11ms/step
# 0.8456
# 1/1 [==============================] - 0s 11ms/step
# 0.6496
# 1/1 [==============================] - 0s 11ms/step
# 0.3118

# %% [markdown]
# # Method B: PCA & SVM

# %% [markdown]
# ## Step 1: Reset data from previous experiment

# %%
X_train = np.load('trnImage.npy')
X_test = np.load('tstImage.npy')

y_train_coarse = np.load('trnLabel_coarse.npy')
y_test_coarse = np.load('tstLabel_coarse.npy')
y_train_fine = np.load('trnLabel_fine.npy')
y_test_fine = np.load('tstLabel_fine.npy')

coarse_list, fine_list = read_text_labels()

# %% [markdown]
# ## Step 2: Perform feature extraction on X_train & X_test data using Hog

# %%
# Loop through training image dataset and create a new numpy array of extracted features
X_train_features = []
for i in range (50000):
    features = skimage.feature.hog(X_train[:,:,:,i], orientations=2, pixels_per_cell=[2,2], cells_per_block=[4,4], visualize=False, channel_axis=-1)
    X_train_features.append(features)
    if i % 10000 == 0:
        print(f"{int((i*2.5)/1000)}% complete")

X_train_features = np.array(X_train_features)
print(f"X_train_features shape: {X_train_features.shape}")
# Out:
# 0% complete
# 25% complete
# 50% complete
# 75% complete
# 100% complete
# X_train_features shape: (50000, 5408)

# %%
# Loop through test image dataset and create a new numpy array of extracted features
X_test_features = []
for i in range (10000):
    features = skimage.feature.hog(X_test[:,:,:,i], orientations=2, pixels_per_cell=[2,2], cells_per_block=[4,4], visualize=False, channel_axis=-1)
    X_test_features.append(features)
    if i % 2500 == 0:
        print(f"{int(i/100)}% complete")

X_test_features = np.array(X_test_features)
print(f"X_train_features shape: {X_train_features.shape}")
# Out:
# 0% complete
# 25% complete
# 50% complete
# 75% complete
# X_train_features shape: (50000, 5408)

# %% [markdown]
# ## Step 3: Use PCA to reduce the dimensionality of the extracted features

# %%
# Create PCA object with 300 components
pca = PCA(n_components=300)

# %%
pca_train = pca.fit_transform(X_train_features)
pca_test = pca.transform(X_test_features)
print(pca_train.shape)
print(pca_test.shape)
# Out:
# (50000, 300)
# (10000, 300)

# %% [markdown]
# ### 300 components (reduced from 5408 features) retains 90% of explained variance

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.03123112, 0.06148774, 0.08525164, 0.10322438, 0.11951838,
#        0.1350025 , 0.14865662, 0.16116446, 0.1729157 , 0.18397306,
#        0.19479126, 0.20542389, 0.21576533, 0.22553465, 0.23492847,
#        0.24362062, 0.25173485, 0.25960985, 0.26694232, 0.27412954,
#        0.28114626, 0.28809243, 0.29501632, 0.3017494 , 0.30828798,
#        0.31475616, 0.32109863, 0.32725036, 0.33330983, 0.33922538,
#        0.3450579 , 0.350744  , 0.35621214, 0.36153546, 0.3668123 ,
#        0.37195516, 0.37702832, 0.38204384, 0.3869896 , 0.39189982,
#        0.39673105, 0.40153614, 0.40625447, 0.4109359 , 0.41554523,
#        0.42007002, 0.42450246, 0.42886862, 0.4331963 , 0.43749166,
#        0.44173887, 0.44584414, 0.4499034 , 0.45389995, 0.45784804,
#        0.46177652, 0.46560147, 0.46937162, 0.47307447, 0.47674483,
#        0.4803995 , 0.4840165 , 0.48762277, 0.4911853 , 0.49470267,
#        0.4981568 , 0.5015915 , 0.50500154, 0.50839245, 0.5117569 ,
#        0.5150674 , 0.51834744, 0.52159464, 0.52481294, 0.527983  ,
#        0.53112805, 0.5342296 , 0.5373196 , 0.54037577, 0.54342586,
#        0.54643345, 0.54942334, 0.5523863 , 0.5553349 , 0.5582359 ,
#        0.5611189 , 0.56399214, 0.5668395 , 0.56968194, 0.5724662 ,
#        0.5752396 , 0.5779591 , 0.580664  , 0.58335316, 0.58603495,
#        0.5887038 , 0.5913538 , 0.5939875 , 0.5966183 , 0.5992244 ,
#        0.6018245 , 0.6044045 , 0.6069794 , 0.60953116, 0.6120716 ,
#        0.6145867 , 0.61709595, 0.61959285, 0.62205195, 0.6245072 ,
#        0.6269609 , 0.62939036, 0.6318158 , 0.6342241 , 0.636626  ,
#        0.63901615, 0.64139307, 0.64374197, 0.6460797 , 0.6484057 ,
#        0.6507203 , 0.65302205, 0.6553125 , 0.65758115, 0.65984046,
#        0.66208863, 0.66432536, 0.6665553 , 0.6687804 , 0.67100245,
#        0.6732036 , 0.6753897 , 0.67756397, 0.67971915, 0.6818525 ,
#        0.6839761 , 0.6860934 , 0.68820554, 0.6903134 , 0.6924038 ,
#        0.6944831 , 0.696555  , 0.69861573, 0.7006755 , 0.7027253 ,
#        0.704758  , 0.70678276, 0.7088054 , 0.710807  , 0.7128072 ,
#        0.7147976 , 0.71678114, 0.7187611 , 0.7207259 , 0.7226826 ,
#        0.72463685, 0.72657096, 0.7284983 , 0.7304084 , 0.7323103 ,
#        0.7342017 , 0.736088  , 0.7379658 , 0.7398337 , 0.74169284,
#        0.74354273, 0.74538255, 0.7472119 , 0.7490332 , 0.75084245,
#        0.7526405 , 0.7544125 , 0.7561816 , 0.757948  , 0.7597049 ,
#        0.761455  , 0.76319706, 0.764935  , 0.766665  , 0.7683802 ,
#        0.7700808 , 0.77176857, 0.7734406 , 0.77510184, 0.77674085,
#        0.7783713 , 0.7799891 , 0.7815931 , 0.78316915, 0.7847305 ,
#        0.78628385, 0.78782743, 0.7893645 , 0.7908796 , 0.79239297,
#        0.79390204, 0.79538894, 0.796863  , 0.7983253 , 0.7997797 ,
#        0.8012294 , 0.8026747 , 0.8041096 , 0.8055286 , 0.806941  ,
#        0.8083369 , 0.8097251 , 0.81109595, 0.8124596 , 0.81381136,
#        0.81513923, 0.8164618 , 0.8177711 , 0.8190654 , 0.8203399 ,
#        0.82160604, 0.8228694 , 0.8241115 , 0.825334  , 0.82652956,
#        0.82771754, 0.8288997 , 0.830067  , 0.83123034, 0.8323888 ,
#        0.8335397 , 0.8346891 , 0.83581376, 0.83693075, 0.8380387 ,
#        0.8391399 , 0.8402239 , 0.841294  , 0.84236014, 0.8434157 ,
#        0.84446293, 0.8455036 , 0.8465398 , 0.8475534 , 0.84856415,
#        0.84956294, 0.8505555 , 0.85153687, 0.85250556, 0.8534704 ,
#        0.8544323 , 0.8553895 , 0.8563391 , 0.85727745, 0.85820514,
#        0.8591254 , 0.86004114, 0.86094594, 0.8618492 , 0.86275077,
#        0.86365104, 0.864541  , 0.86542517, 0.86629957, 0.8671532 ,
#        0.8680012 , 0.86884207, 0.86967933, 0.870506  , 0.8713321 ,
#        0.8721527 , 0.8729683 , 0.8737805 , 0.87458545, 0.87536657,
#        0.87613827, 0.8768982 , 0.8776505 , 0.87839246, 0.8791282 ,
#        0.8798562 , 0.8805774 , 0.88129747, 0.88200265, 0.88270396,
#        0.8833994 , 0.88409   , 0.88477737, 0.8854614 , 0.88614327,
#        0.8868235 , 0.8874935 , 0.88815093, 0.8888061 , 0.8894535 ,
#        0.89009994, 0.8907444 , 0.8913775 , 0.89200634, 0.8926328 ,
#        0.8932542 , 0.89387035, 0.8944808 , 0.89508736, 0.8956895 ],
#       dtype=float32)

# %% [markdown]
# ## Step 4: Create SVM Classifier & fit to PCA data

# %%
# Coarse labels
svc_model_coarse = SVC()
svc_model_coarse.fit(pca_train, y_train_coarse)
# Out:
# SVC()

# %%
# fine labels
svc_model_fine = SVC()
svc_model_fine.fit(pca_train, y_train_fine)
# Out:
# SVC()

# %%
# predict using pca_test
predictions_test_coarse = svc_model_coarse.predict(pca_test)
predictions_test_fine = svc_model_fine.predict(pca_test)

# %% [markdown]
# ## Step 5: Evaluate results

# %% [markdown]
# ### Show classification Report for Coarse labels

# %%
print(classification_report(y_test_coarse,predictions_test_coarse))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.21      0.20      0.20       500
#            1       0.28      0.26      0.27       500
#            2       0.24      0.23      0.24       500
#            3       0.51      0.57      0.54       500
#            4       0.42      0.33      0.37       500
#            5       0.37      0.31      0.34       500
#            6       0.36      0.41      0.38       500
#            7       0.26      0.25      0.26       500
#            8       0.19      0.32      0.24       500
#            9       0.33      0.42      0.37       500
#           10       0.34      0.36      0.35       500
#           11       0.17      0.16      0.16       500
#           12       0.15      0.13      0.14       500
#           13       0.26      0.14      0.19       500
#           14       0.33      0.35      0.34       500
#           15       0.24      0.15      0.18       500
#           16       0.18      0.18      0.18       500
#           17       0.42      0.54      0.47       500
#           18       0.38      0.38      0.38       500
#           19       0.32      0.29      0.30       500
#
#     accuracy                           0.30     10000
#    macro avg       0.30      0.30      0.29     10000
# weighted avg       0.30      0.30      0.29     10000

# %% [markdown]
# ### Show Confusion Matrix for Coarse labels

# %%
coarse_confusion_matrix = confusion_matrix(y_test_coarse,predictions_test_coarse, normalize='pred')
coarse_matrix_plot = ConfusionMatrixDisplay(confusion_matrix=coarse_confusion_matrix, display_labels=coarse_list)
fig, ax = plt.subplots(figsize=(12,10))
plt.title("Confusion Matrix for SVM trained on coarse labels")
coarse_matrix_plot.plot(ax=ax, xticks_rotation='vertical', values_format= '.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ### Show classification Report for Fine labels

# %%
print(classification_report(y_test_fine,predictions_test_fine))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.53      0.52       100
#            1       0.22      0.31      0.26       100
#            2       0.07      0.04      0.05       100
#            3       0.05      0.04      0.04       100
#            4       0.04      0.03      0.04       100
#            5       0.14      0.18      0.16       100
#            6       0.04      0.06      0.05       100
#            7       0.07      0.06      0.07       100
#            8       0.37      0.41      0.39       100
#            9       0.58      0.45      0.51       100
#           10       0.27      0.34      0.30       100
#           11       0.13      0.11      0.12       100
#           12       0.15      0.15      0.15       100
#           13       0.15      0.14      0.15       100
#           14       0.16      0.17      0.16       100
#           15       0.20      0.13      0.16       100
#           16       0.42      0.30      0.35       100
#           17       0.21      0.31      0.25       100
#           18       0.07      0.06      0.06       100
#           19       0.12      0.15      0.14       100
#           20       0.43      0.60      0.50       100
#           21       0.22      0.19      0.20       100
#           22       0.40      0.34      0.37       100
#           23       0.10      0.08      0.09       100
#           24       0.33      0.53      0.41       100
#           25       0.27      0.23      0.25       100
#           26       0.30      0.14      0.19       100
#           27       0.11      0.15      0.12       100
#           28       0.48      0.61      0.54       100
#           29       0.39      0.31      0.34       100
#           30       0.08      0.11      0.09       100
#           31       0.11      0.13      0.12       100
#           32       0.19      0.20      0.19       100
#           33       0.10      0.36      0.16       100
#           34       0.08      0.10      0.09       100
#           35       0.05      0.05      0.05       100
#           36       0.14      0.21      0.17       100
#           37       0.11      0.09      0.10       100
#           38       0.05      0.10      0.07       100
#           39       0.35      0.21      0.26       100
#           40       0.29      0.32      0.30       100
#           41       0.69      0.50      0.58       100
#           42       0.05      0.08      0.06       100
#           43       0.09      0.11      0.10       100
#           44       0.10      0.10      0.10       100
#           45       0.19      0.09      0.12       100
#           46       0.16      0.12      0.14       100
#           47       0.19      0.24      0.21       100
#           48       0.50      0.50      0.50       100
#           49       0.15      0.13      0.14       100
#           50       0.06      0.03      0.04       100
#           51       0.09      0.08      0.08       100
#           52       0.26      0.42      0.32       100
#           53       0.22      0.19      0.21       100
#           54       0.15      0.08      0.10       100
#           55       0.03      0.01      0.01       100
#           56       0.16      0.26      0.20       100
#           57       0.27      0.26      0.27       100
#           58       0.29      0.37      0.33       100
#           59       0.22      0.17      0.19       100
#           60       0.35      0.30      0.32       100
#           61       0.43      0.58      0.50       100
#           62       0.12      0.10      0.11       100
#           63       0.11      0.21      0.14       100
#           64       0.02      0.01      0.01       100
#           65       0.09      0.08      0.08       100
#           66       0.10      0.07      0.08       100
#           67       0.07      0.03      0.04       100
#           68       0.48      0.65      0.55       100
#           69       0.41      0.56      0.47       100
#           70       0.11      0.15      0.13       100
#           71       0.33      0.36      0.35       100
#           72       0.02      0.01      0.01       100
#           73       0.23      0.18      0.20       100
#           74       0.17      0.14      0.15       100
#           75       0.24      0.15      0.19       100
#           76       0.35      0.48      0.41       100
#           77       0.07      0.05      0.06       100
#           78       0.07      0.04      0.05       100
#           79       0.21      0.30      0.25       100
#           80       0.04      0.03      0.03       100
#           81       0.18      0.15      0.16       100
#           82       0.43      0.20      0.27       100
#           83       0.06      0.03      0.04       100
#           84       0.08      0.06      0.07       100
#           85       0.15      0.17      0.16       100
#           86       0.33      0.42      0.37       100
#           87       0.35      0.25      0.29       100
#           88       0.10      0.17      0.13       100
#           89       0.08      0.09      0.08       100
#           90       0.35      0.23      0.28       100
#           91       0.43      0.30      0.36       100
#           92       0.12      0.14      0.13       100
#           93       0.11      0.04      0.06       100
#           94       0.39      0.34      0.36       100
#           95       0.23      0.19      0.21       100
#           96       0.10      0.11      0.10       100
#           97       0.25      0.18      0.21       100
#           98       0.11      0.09      0.10       100
#           99       0.39      0.26      0.31       100
#
#     accuracy                           0.21     10000
#    macro avg       0.21      0.21      0.20     10000
# weighted avg       0.21      0.21      0.20     10000

# %% [markdown]
# ### Show Confusion Matrix for Fine labels

# %%
fine_confusion_matrix = confusion_matrix(y_test_fine,predictions_test_fine, normalize='pred')
rand_i = np.random.randint(0, 79)
print(rand_i)


first_20_matrix = fine_confusion_matrix[rand_i: rand_i+20, rand_i: rand_i+20]

fine_matrix_plot = ConfusionMatrixDisplay(confusion_matrix=first_20_matrix, display_labels=fine_list[rand_i:rand_i+20])
fig, ax = plt.subplots(figsize=(12,10))
fine_matrix_plot.plot(ax=ax, xticks_rotation='vertical', values_format='.2f', cmap="Blues")
plt.show()
# Out:
# 52
